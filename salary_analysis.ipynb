# %% [markdown]
# Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')

X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# Training the linear regression model on the whole dataset

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, y)
# Out:
# LinearRegression()

# %% [markdown]
# Training the Ploynomial Regression model on the whole dataset

# %%
poly_reg = PolynomialFeatures(degree= 4)
X_poly = poly_reg.fit_transform(X)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(X_poly, y)
# Out:
# LinearRegression()

# %% [markdown]
# Visualizing the Linear Regression Model

# %%
plt.scatter(X, y, color = 'red')
plt.plot(X, lin_reg.predict(X), color='blue')
plt.title('Truth or Bluff of Salaries (Linear Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')

plt.show()

# %% [markdown]
# Visualizing Polynomial Regression Model

# %%
plt.scatter(X, y, color='red')
plt.plot(X, lin_reg_2.predict(poly_reg.fit_transform(X)), color='blue')
plt.title('Truth or Bluff of Salaries (Polynomial Regression)')
plt.xlabel('Position Level')
plt.ylabel('Salary')

plt.show()

# %% [markdown]
# Visualizing Polynomial Regression with a smoother curve

# %%
X_grid = np.arange(min(X), max(X), 0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X , y, color='red')
plt.plot(X_grid, lin_reg_2.predict(poly_reg.fit_transform(X_grid)), color= 'blue')
plt.title('Truth or Bluff (Polynomial Regression)')
plt.xlabel('Position level')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# Predicting a new result with a Linear Regression

# %%
lin_reg.predict([[6.5]])

# Shows us that the linear regression prediction is way off of what the actual results were
# Out:
# array([330378.78787879])

# %% [markdown]
# Predicting a new result with a Polynomial Regression

# %%
lin_reg_2.predict(poly_reg.fit_transform([[6.5]]))

# the person mentioned their previous salary that was close to out prediction and we can conclude that they are not lying. They earned the same amount of money, and did not lie to us.
# Out:
# array([158862.4526515])
